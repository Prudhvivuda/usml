# %%
import pandas as pd

# Load the dataset
file_path = 'data.csv'
data = pd.read_csv(file_path, encoding='ascii')

# Display the first few rows of the dataset
data.head()
# Out:
#    id      f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0   0 -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560
# 1   1 -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651
# 2   2  0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301
# 3   3 -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850
# 4   4 -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898
#
#    f_07  f_08  ...      f_19      f_20      f_21      f_22      f_23  \
# 0     2    13  ... -0.478412 -0.757002 -0.763635 -1.090369  1.142641
# 1     2     3  ... -0.428791 -0.089908 -1.784204 -0.839474  0.459685
# 2     5    11  ... -0.413534 -1.602377  1.190984  3.267116 -0.088322
# 3     6     2  ...  0.619283  1.287801  0.532837  1.036631 -2.041828
# 4     8     7  ... -1.628830 -0.434948  0.322505  0.284326 -2.438365
#
#        f_24      f_25      f_26      f_27      f_28
# ...

# %%
# Check for missing values and get a summary of the dataset
data_info = data.info()
missing_values = data.isnull().sum()

# Display the summary of missing values
print(missing_values)

# Summary statistics of the dataset
descriptive_stats = data.describe()
descriptive_stats
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98000 entries, 0 to 97999
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      98000 non-null  int64
#  1   f_00    98000 non-null  float64
#  2   f_01    98000 non-null  float64
#  3   f_02    98000 non-null  float64
#  4   f_03    98000 non-null  float64
#  5   f_04    98000 non-null  float64
#  6   f_05    98000 non-null  float64
#  7   f_06    98000 non-null  float64
#  8   f_07    98000 non-null  int64
#  9   f_08    98000 non-null  int64
#  10  f_09    98000 non-null  int64
#  11  f_10    98000 non-null  int64
#  12  f_11    98000 non-null  int64
#  13  f_12    98000 non-null  int64
#  14  f_13    98000 non-null  int64
#  15  f_14    98000 non-null  float64
#  16  f_15    98000 non-null  float64
#  17  f_16    98000 non-null  float64
#  18  f_17    98000 non-null  float64
#  19  f_18    98000 non-null  float64
#  20  f_19    98000 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select a subset of features for visualization
data_subset = data[['f_00', 'f_01', 'f_02', 'f_03', 'f_04']]

# Plot distributions of the selected features
plt.figure(figsize=(15, 10))
for i, column in enumerate(data_subset.columns, 1):
    plt.subplot(2, 3, i)
    sns.histplot(data_subset[column], kde=True, bins=30)
    plt.title('Distribution of ' + column)

plt.tight_layout()
plt.show()

# Correlation matrix of the selected features
corr_matrix = data_subset.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Selected Features')
plt.show()

# %%
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import numpy as np

# Preprocess the data: Standardization
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data.drop(['id'], axis=1))

# Determine the optimal number of components for GMM using Silhouette Score
n_components = range(2, 11)
silhouette_scores = []

for n in n_components:
    gmm = GaussianMixture(n_components=n, random_state=42)
    gmm_labels = gmm.fit_predict(data_scaled)
    silhouette_scores.append(silhouette_score(data_scaled, gmm_labels))

# Plot the silhouette scores for different numbers of components
plt.figure(figsize=(10, 6))
plt.plot(n_components, silhouette_scores, marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores for Different Numbers of GMM Components')
plt.show()

# %%
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import numpy as np
import matplotlib.pyplot as plt

# Preprocess the data: Standardization
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data.drop(['id'], axis=1))

# Determine the optimal number of components for GMM using Silhouette Score
n_components = range(2, 11)
silhouette_scores = []
gmm_models = []

for n in n_components:
    gmm = GaussianMixture(n_components=n, random_state=42)
    gmm_labels = gmm.fit_predict(data_scaled)
    silhouette_scores.append(silhouette_score(data_scaled, gmm_labels))
    gmm_models.append(gmm)

# Find the best model based on the highest silhouette score
best_model_index = np.argmax(silhouette_scores)
best_model = gmm_models[best_model_index]
best_n_components = n_components[best_model_index]

# Plot the Gaussian Mixture Model highlighting centers and clusters
plt.figure(figsize=(10, 6))
colors = plt.cm.Spectral(np.linspace(0, 1, best_n_components))

for i in range(best_n_components):
    plt.scatter(data_scaled[:, 0], data_scaled[:, 1], c=gmm_labels, s=40, cmap='viridis', alpha=0.5)
    plt.scatter(best_model.means_[i, 0], best_model.means_[i, 1], s=200, c='red', marker='*', label=f'Center {i+1}')

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'Gaussian Mixture Model with {best_n_components} Components')
plt.legend()
plt.show()
